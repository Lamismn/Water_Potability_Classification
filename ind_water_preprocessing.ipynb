# %%
import pandas as pd
import numpy as np

# %%
data_raw = pd.read_csv("Resources/raw_files/Water_compiled.csv")
data_raw
# Out:
#       STATION CODE                                          LOCATIONS  \
# 0           1312.0  GODAVARI AT JAYAKWADI DAM, AURNaNGABAD,MAHARAS...
# 1           2177.0              GODAVARI RIVER NEAR SOMESHWAR TEMPLE.
# 2           2182.0                        GODAVARI RIVER AT SAIKHEDA.
# 3           2179.0      GODAVARI RIVER AT HANUMAN GHAT, NaNSHIK CITY.
# 4           2183.0          GODAVARI RIVER AT NaNDUR- MADMESHWAR DAM.
# ...            ...                                                ...
# 2519        1330.0           TAMBIRAPARANI AT ARUMUGANERI, TAMILNaNDU
# 2520        1450.0  PALAR AT VANIYAMBADI WATER SUPPLY HEAD WORK, T...
# 2521        1403.0                 GUMTI AT U/S SOUTH TRIPURA,TRIPURA
# 2522        1404.0                GUMTI AT D/S SOUTH TRIPURA, TRIPURA
# 2523        1726.0   CHANDRAPUR, AGARTALA D/S OF HAORA RIVER, TRIPURA
#
#             STATE  TEMP   DO     pH  CONDUCTIVITY  BOD NITRATE_N_NITRITE_N  \
# ...

# %%
#Checking for duplicates
duplicate = data_raw[data_raw.duplicated(['STATE', 'TEMP', 'DO', 'pH', 'CONDUCTIVITY', 'BOD', 'NITRATE_N_NITRITE_N', 'FECAL_COLIFORM', 'TOTAL_COLIFORM'])]
duplicate
# Out:
#       STATION CODE                                          LOCATIONS  \
# 535         1399.0  ZUARI AT D/S OF PT. WHERE KUMBARJRIA CANaNL JO...
# 536         1475.0                                ZUARI AT PANCHAWADI
# 537         3181.0                        RIVER ZUARI AT BORIM BRIDGE
# 538         3182.0                       RIVER ZUARI AT MARCAIM JETTY
# 539         1400.0            MANDOVI AT NEGHBOURHOOD OF PANaNJI, GOA
# ...            ...                                                ...
# 728         2947.0        RIVER JAWAI AT JAWAI DAM, SIROHI, RAJASTHAN
# 729         1717.0                    KODRA DAM, MOUNT ABU, RAJASTHAN
# 730         2948.0        RIVER BANDI AT HEMAWAS DAM, PALI, RAJASTHAN
# 731         2949.0  RIVER LUNI AT RANaNKPUR DAM, RANaNKPUR, PALI, ...
# 2445           NaN                                                NaN
#
#           STATE  TEMP   DO   pH  CONDUCTIVITY  BOD NITRATE_N_NITRITE_N  \
# ...

# %%
# Drop duplicate columns
data_noduplicates = data_raw.drop_duplicates(subset = ['STATE', 'TEMP', 'DO', 'pH', 'CONDUCTIVITY', 'BOD', 'NITRATE_N_NITRITE_N', 'FECAL_COLIFORM', 'TOTAL_COLIFORM'])
data_noduplicates
# Out:
#       STATION CODE                                          LOCATIONS  \
# 0           1312.0  GODAVARI AT JAYAKWADI DAM, AURNaNGABAD,MAHARAS...
# 1           2177.0              GODAVARI RIVER NEAR SOMESHWAR TEMPLE.
# 2           2182.0                        GODAVARI RIVER AT SAIKHEDA.
# 3           2179.0      GODAVARI RIVER AT HANUMAN GHAT, NaNSHIK CITY.
# 4           2183.0          GODAVARI RIVER AT NaNDUR- MADMESHWAR DAM.
# ...            ...                                                ...
# 2519        1330.0           TAMBIRAPARANI AT ARUMUGANERI, TAMILNaNDU
# 2520        1450.0  PALAR AT VANIYAMBADI WATER SUPPLY HEAD WORK, T...
# 2521        1403.0                 GUMTI AT U/S SOUTH TRIPURA,TRIPURA
# 2522        1404.0                GUMTI AT D/S SOUTH TRIPURA, TRIPURA
# 2523        1726.0   CHANDRAPUR, AGARTALA D/S OF HAORA RIVER, TRIPURA
#
#             STATE  TEMP   DO     pH  CONDUCTIVITY  BOD NITRATE_N_NITRITE_N  \
# ...

# %%
data_noduplicates.isna().sum()
# Out:
# STATION CODE           120
# LOCATIONS              182
# STATE                  759
# TEMP                     0
# DO                      31
# pH                       6
# CONDUCTIVITY            53
# BOD                     44
# NITRATE_N_NITRITE_N    220
# FECAL_COLIFORM         379
# TOTAL_COLIFORM         158
# dtype: int64

# %%
data_clean = data_noduplicates.dropna()
data_clean
# Out:
#       STATION CODE                                          LOCATIONS  \
# 0           1312.0  GODAVARI AT JAYAKWADI DAM, AURNaNGABAD,MAHARAS...
# 1           2177.0              GODAVARI RIVER NEAR SOMESHWAR TEMPLE.
# 2           2182.0                        GODAVARI RIVER AT SAIKHEDA.
# 3           2179.0      GODAVARI RIVER AT HANUMAN GHAT, NaNSHIK CITY.
# 4           2183.0          GODAVARI RIVER AT NaNDUR- MADMESHWAR DAM.
# ...            ...                                                ...
# 1574        1148.0                               AMBIKA AT BILIMORA,
# 1576        1438.0          MINDHOLA AT STATE HIGHWAY BRIDGE SACHIN,
# 1742        1633.0                        SIMSANG RIVER WILLIAMNaNGAR
# 1748        1404.0                         GUMTI AT D/S SOUTH TRIPURA
# 1749        1726.0   CHANDRAPUR, AGARTALA D/S OF HAORA RIVER, TRIPURA
#
#             STATE  TEMP    DO    pH  CONDUCTIVITY   BOD NITRATE_N_NITRITE_N  \
# ...

# %%
data_clean.set_index(['STATION CODE'])
# Out:
#                                                       LOCATIONS        STATE  \
# STATION CODE
# 1312.0        GODAVARI AT JAYAKWADI DAM, AURNaNGABAD,MAHARAS...  MAHARASHTRA
# 2177.0                    GODAVARI RIVER NEAR SOMESHWAR TEMPLE.  MAHARASHTRA
# 2182.0                              GODAVARI RIVER AT SAIKHEDA.  MAHARASHTRA
# 2179.0            GODAVARI RIVER AT HANUMAN GHAT, NaNSHIK CITY.  MAHARASHTRA
# 2183.0                GODAVARI RIVER AT NaNDUR- MADMESHWAR DAM.  MAHARASHTRA
# ...                                                         ...          ...
# 1148.0                                     AMBIKA AT BILIMORA,       GUJARAT
# 1438.0                MINDHOLA AT STATE HIGHWAY BRIDGE SACHIN,       GUJARAT
# 1633.0                              SIMSANG RIVER WILLIAMNaNGAR      MIZORAM
# 1404.0                               GUMTI AT D/S SOUTH TRIPURA      tripura
# 1726.0         CHANDRAPUR, AGARTALA D/S OF HAORA RIVER, TRIPURA      tripura
#
# ...

# %%
data_clean.to_csv('Resources/Preprocessed/in_water_cleaned.csv', mode = "w", sep = "|", index = False)

# %%
data_clean.dtypes
# Out:
# STATION CODE           float64
# LOCATIONS               object
# STATE                   object
# TEMP                   float64
# DO                     float64
# pH                     float64
# CONDUCTIVITY           float64
# BOD                     object
# NITRATE_N_NITRITE_N     object
# FECAL_COLIFORM          object
# TOTAL_COLIFORM          object
# dtype: object

# %%
data_clean['BOD'] = pd.to_numeric(data_clean['BOD'], errors = 'coerce')
# Out:
# C:\Users\lamis\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_clean['NITRATE_N_NITRITE_N'] = pd.to_numeric(data_clean['NITRATE_N_NITRITE_N'], errors = 'coerce')
# Out:
# C:\Users\lamis\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_clean['FECAL_COLIFORM'] = pd.to_numeric(data_clean['FECAL_COLIFORM'], errors = 'coerce')
# Out:
# C:\Users\lamis\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_clean['TOTAL_COLIFORM'] = pd.to_numeric(data_clean['TOTAL_COLIFORM'], errors = 'coerce')
# Out:
# C:\Users\lamis\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_clean.dtypes
# Out:
# STATION CODE           float64
# LOCATIONS               object
# STATE                   object
# TEMP                   float64
# DO                     float64
# pH                     float64
# CONDUCTIVITY           float64
# BOD                    float64
# NITRATE_N_NITRITE_N    float64
# FECAL_COLIFORM         float64
# TOTAL_COLIFORM         float64
# dtype: object

# %%
data_clean.columns
# Out:
# Index(['STATION CODE', 'LOCATIONS', 'STATE', 'TEMP', 'DO', 'pH',
#        'CONDUCTIVITY', 'BOD', 'NITRATE_N_NITRITE_N', 'FECAL_COLIFORM',
#        'TOTAL_COLIFORM'],
#       dtype='object')

# %%
water_par = data_clean[['STATION CODE', 'DO', 'pH',
       'CONDUCTIVITY', 'BOD', 'NITRATE_N_NITRITE_N',
       'TOTAL_COLIFORM']]
water_par.head()
# Out:
#    STATION CODE   DO   pH  CONDUCTIVITY  BOD  NITRATE_N_NITRITE_N  \
# 0        1312.0  6.4  8.1         735.0  3.4                 2.00
# 1        2177.0  6.0  8.0         270.0  3.1                 2.00
# 2        2182.0  5.5  7.8         355.0  4.2                 9.00
# 3        2179.0  5.5  7.8         371.0  5.6                 3.55
# 4        2183.0  5.7  7.9         294.0  3.2                 2.69
#
#    TOTAL_COLIFORM
# 0            73.0
# 1           182.0
# 2           133.0
# 3           283.0
# 4           132.0

# %%
water_par.set_index(['STATION CODE'])
# Out:
#                 DO    pH  CONDUCTIVITY   BOD  NITRATE_N_NITRITE_N  \
# STATION CODE
# 1312.0        6.40  8.10         735.0  3.40                 2.00
# 2177.0        6.00  8.00         270.0  3.10                 2.00
# 2182.0        5.50  7.80         355.0  4.20                 9.00
# 2179.0        5.50  7.80         371.0  5.60                 3.55
# 2183.0        5.70  7.90         294.0  3.20                 2.69
# ...            ...   ...           ...   ...                  ...
# 1148.0        6.20  7.80        7778.0  2.70                 0.26
# 1438.0        3.20  7.70         885.0  6.30                 0.51
# 1633.0        8.23  7.38         143.0  1.55                 3.55
# 1404.0        6.20  7.70         176.0  3.50                 0.20
# 1726.0        6.30  8.00         198.0  4.20                 0.30
#
#               TOTAL_COLIFORM
# STATION CODE
# 1312.0                  73.0
# 2177.0                 182.0
# 2182.0                 133.0
# ...

# %%
water_par.to_csv('Resources/Preprocessed/water_contents.csv', mode = 'w', index = False)

# %%
station_location = data_clean[['STATION CODE', 'LOCATIONS', 'STATE']]
station_location.head()
# Out:
#    STATION CODE                                          LOCATIONS  \
# 0        1312.0  GODAVARI AT JAYAKWADI DAM, AURNaNGABAD,MAHARAS...
# 1        2177.0              GODAVARI RIVER NEAR SOMESHWAR TEMPLE.
# 2        2182.0                        GODAVARI RIVER AT SAIKHEDA.
# 3        2179.0      GODAVARI RIVER AT HANUMAN GHAT, NaNSHIK CITY.
# 4        2183.0          GODAVARI RIVER AT NaNDUR- MADMESHWAR DAM.
#
#          STATE
# 0  MAHARASHTRA
# 1  MAHARASHTRA
# 2  MAHARASHTRA
# 3  MAHARASHTRA
# 4  MAHARASHTRA

# %%
station_location.set_index(['STATION CODE'])
# Out:
#                                                       LOCATIONS        STATE
# STATION CODE
# 1312.0        GODAVARI AT JAYAKWADI DAM, AURNaNGABAD,MAHARAS...  MAHARASHTRA
# 2177.0                    GODAVARI RIVER NEAR SOMESHWAR TEMPLE.  MAHARASHTRA
# 2182.0                              GODAVARI RIVER AT SAIKHEDA.  MAHARASHTRA
# 2179.0            GODAVARI RIVER AT HANUMAN GHAT, NaNSHIK CITY.  MAHARASHTRA
# 2183.0                GODAVARI RIVER AT NaNDUR- MADMESHWAR DAM.  MAHARASHTRA
# ...                                                         ...          ...
# 1148.0                                     AMBIKA AT BILIMORA,       GUJARAT
# 1438.0                MINDHOLA AT STATE HIGHWAY BRIDGE SACHIN,       GUJARAT
# 1633.0                              SIMSANG RIVER WILLIAMNaNGAR      MIZORAM
# 1404.0                               GUMTI AT D/S SOUTH TRIPURA      tripura
# 1726.0         CHANDRAPUR, AGARTALA D/S OF HAORA RIVER, TRIPURA      tripura
#
# [1266 rows x 2 columns]

# %%
station_location.to_csv('Resources/Preprocessed/station_locations.csv',mode = 'w', index = False)

# %%
# water_par[(water_par['DO']>=6) & (water_par['pH'] < 8.5) & (water_par['pH']>6.5) & (water_par['BOD']<2) & (water_par['TOTAL_COLIFORM']<50)]

def grade(water_par):
    if water_par['DO'] >= 6 and water_par['pH']<8.5 and water_par['pH']>6.5 and water_par['BOD']<2 and water_par['TOTAL_COLIFORM']<50:
        return 'A'
    elif water_par['DO'] >= 5 and water_par['pH']<8.5 and water_par['pH']>6.5 and water_par['BOD']<3 and water_par['TOTAL_COLIFORM']<500:
        return 'B'
    elif water_par['DO'] >= 4 and water_par['pH']<9 and water_par['pH']>6 and water_par['BOD']<3 and water_par['TOTAL_COLIFORM']<5000:
        return 'C'
    elif water_par['pH']<8.5 and water_par['pH']>6.5 and water_par['DO'] >= 4 and water_par['NITRATE_N_NITRITE_N']<1.2 and water_par['TOTAL_COLIFORM']<50000:
        return 'D'
    elif water_par['pH']<8.5 and water_par['pH']>6 and water_par['CONDUCTIVITY'] < 2250 and water_par['NITRATE_N_NITRITE_N']<2 and water_par['TOTAL_COLIFORM']<60000:
        return 'E'
    else:
        return 'F'
   

water_par['Grade'] = water_par.apply(grade, axis = 1)

water_par
# Out:
# C:\Users\lamis\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       STATION CODE    DO    pH  CONDUCTIVITY   BOD  NITRATE_N_NITRITE_N  \
# 0           1312.0  6.40  8.10         735.0  3.40                 2.00
# 1           2177.0  6.00  8.00         270.0  3.10                 2.00
# 2           2182.0  5.50  7.80         355.0  4.20                 9.00
# 3           2179.0  5.50  7.80         371.0  5.60                 3.55
# 4           2183.0  5.70  7.90         294.0  3.20                 2.69
# ...            ...   ...   ...           ...   ...                  ...
# 1574        1148.0  6.20  7.80        7778.0  2.70                 0.26
# ...

# %%
water_par.set_index(['STATION CODE'])
# Out:
#                 DO    pH  CONDUCTIVITY   BOD  NITRATE_N_NITRITE_N  \
# STATION CODE
# 1312.0        6.40  8.10         735.0  3.40                 2.00
# 2177.0        6.00  8.00         270.0  3.10                 2.00
# 2182.0        5.50  7.80         355.0  4.20                 9.00
# 2179.0        5.50  7.80         371.0  5.60                 3.55
# 2183.0        5.70  7.90         294.0  3.20                 2.69
# ...            ...   ...           ...   ...                  ...
# 1148.0        6.20  7.80        7778.0  2.70                 0.26
# 1438.0        3.20  7.70         885.0  6.30                 0.51
# 1633.0        8.23  7.38         143.0  1.55                 3.55
# 1404.0        6.20  7.70         176.0  3.50                 0.20
# 1726.0        6.30  8.00         198.0  4.20                 0.30
#
#               TOTAL_COLIFORM Grade
# STATION CODE
# 1312.0                  73.0     F
# 2177.0                 182.0     F
# 2182.0                 133.0     F
# ...

# %%
water_grade = water_par[['STATION CODE', 'Grade']]
water_grade.set_index(['STATION CODE'])
# Out:
#              Grade
# STATION CODE
# 1312.0           F
# 2177.0           F
# 2182.0           F
# 2179.0           F
# 2183.0           F
# ...            ...
# 1148.0           D
# 1438.0           E
# 1633.0           B
# 1404.0           D
# 1726.0           D
#
# [1266 rows x 1 columns]

# %%
water_grade.to_csv('Resources/Preprocessed/water_grade.csv', mode = 'w', index = False)

# %%
def water_pot(water_par):
    if water_par['Grade'] == 'A' or water_par['Grade'] == 'C' or water_par['Grade'] == 'B':
        return 1
    else:
        return 0
    
water_par['Potability'] = water_par.apply(water_pot, axis = 1)

water_par
# Out:
# C:\Users\lamis\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#       STATION CODE    DO    pH  CONDUCTIVITY   BOD  NITRATE_N_NITRITE_N  \
# 0           1312.0  6.40  8.10         735.0  3.40                 2.00
# 1           2177.0  6.00  8.00         270.0  3.10                 2.00
# 2           2182.0  5.50  7.80         355.0  4.20                 9.00
# 3           2179.0  5.50  7.80         371.0  5.60                 3.55
# 4           2183.0  5.70  7.90         294.0  3.20                 2.69
# ...            ...   ...   ...           ...   ...                  ...
# 1574        1148.0  6.20  7.80        7778.0  2.70                 0.26
# ...

# %%
water_potability = water_par[['STATION CODE', 'Potability']]
water_potability.set_index(['STATION CODE'])

water_potability
# Out:
#       STATION CODE  Potability
# 0           1312.0           0
# 1           2177.0           0
# 2           2182.0           0
# 3           2179.0           0
# 4           2183.0           0
# ...            ...         ...
# 1574        1148.0           0
# 1576        1438.0           0
# 1742        1633.0           1
# 1748        1404.0           0
# 1749        1726.0           0
#
# [1266 rows x 2 columns]

# %%
water_potability.to_csv('Resources/Preprocessed/station_potability.csv', mode = 'w', index = False)

# %%
data_clean['STATE'].unique()
# Out:
# array(['MAHARASHTRA', 'ANDHRA PRADESH', 'UTTAR PRADESH', 'BIHAR',
#        'WEST BENGAL', 'ASSAM', 'KARNaNTAKA', 'HIMACHAL PRADESH', 'KERALA',
#        'TAMILNaNDU', 'MADHYA PRADESH', 'RAJASTHAN', 'PUNJAB', 'GOA',
#        'GUJARAT', 'ODISHA', 'MEGHALAYA', 'MIZORAM', 'TRIPURA', 'ORISSA',
#        'DAMAN & DIU', 'PONDICHERRY', 'HARYANaN',
#        'DAMAN, DIU, DADRA NaNGAR HAVELI', 'TAMIL NaNDU', 'tripura'],
#       dtype=object)

# %%
station_loc = data_clean[['STATION CODE', 'LOCATIONS', 'STATE']]
station_loc
# Out:
#       STATION CODE                                          LOCATIONS  \
# 0           1312.0  GODAVARI AT JAYAKWADI DAM, AURNaNGABAD,MAHARAS...
# 1           2177.0              GODAVARI RIVER NEAR SOMESHWAR TEMPLE.
# 2           2182.0                        GODAVARI RIVER AT SAIKHEDA.
# 3           2179.0      GODAVARI RIVER AT HANUMAN GHAT, NaNSHIK CITY.
# 4           2183.0          GODAVARI RIVER AT NaNDUR- MADMESHWAR DAM.
# ...            ...                                                ...
# 1574        1148.0                               AMBIKA AT BILIMORA,
# 1576        1438.0          MINDHOLA AT STATE HIGHWAY BRIDGE SACHIN,
# 1742        1633.0                        SIMSANG RIVER WILLIAMNaNGAR
# 1748        1404.0                         GUMTI AT D/S SOUTH TRIPURA
# 1749        1726.0   CHANDRAPUR, AGARTALA D/S OF HAORA RIVER, TRIPURA
#
#             STATE
# 0     MAHARASHTRA
# 1     MAHARASHTRA
# 2     MAHARASHTRA
# 3     MAHARASHTRA
# 4     MAHARASHTRA
# ...
